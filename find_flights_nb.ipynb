# %%
# import vaex

# import numpy as np
# import pylab as plt
import csv
from collections import defaultdict
# import seaborn as sns

# %%
flights = defaultdict(list)

# %%
origins = []
destinations = []
distances = {}

# %%
with open('airlines.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
#             print(f'\t{row[0]} works in the {row[1]} department, and was born in {row[2]}.')
#             print(row)
            origin = row[2]
            dest = row[4]
            distance = row[-2]
            if dest not in flights[origin]:
                flights[origin].append(dest)
            if origin not in origins:
                origins.append(origin)
            if dest not in destinations:
                destinations.append(dest)
            distances[(origin, dest)] = distance
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Column names are OP_UNIQUE_CARRIER, ORIGIN_AIRPORT_ID, ORIGIN_CITY_NAME, DEST_AIRPORT_ID, DEST_CITY_NAME, AIR_TIME, DISTANCE,
# Processed 607347 lines.

# %%
print(distances)
# Out:
# ['Boston, MA', 'New York, NY', 'Atlanta, GA', 'Fort Myers, FL', 'Minneapolis, MN', 'Punta Gorda, FL', 'Orlando, FL', 'Fort Lauderdale, FL', 'Sanford, FL', 'Philadelphia, PA', 'Tampa, FL', 'Charlotte, NC', 'Baltimore, MD', 'Newark, NJ', 'Detroit, MI', 'Washington, DC', 'Chicago, IL']
# {('Appleton, WI', 'Atlanta, GA'): '765.00', ('New York, NY', 'Portland, ME'): '269.00', ('Detroit, MI', 'Des Moines, IA'): '534.00', ('Detroit, MI', 'Traverse City, MI'): '207.00', ('Traverse City, MI', 'Detroit, MI'): '207.00', ('Atlanta, GA', 'White Plains, NY'): '780.00', ('Cleveland, OH', 'New York, NY'): '419.00', ('White Plains, NY', 'Atlanta, GA'): '780.00', ('New York, NY', 'Cleveland, OH'): '419.00', ('Atlanta, GA', 'Evansville, IN'): '350.00', ('Cincinnati, OH', 'Newark, NJ'): '569.00', ('Evansville, IN', 'Atlanta, GA'): '350.00', ('Cincinnati, OH', 'Boston, MA'): '752.00', ('Detroit, MI', 'Baltimore, MD'): '409.00', ('Indianapolis, IN', 'Detroit, MI'): '231.00', ('Alexandria, LA', 'Atlanta, GA'): '500.00', ('Cleveland, OH', 'Boston, MA'): '563.00', ('Richmond, VA', 'Minneapolis, MN'): '970.00', ('New York, NY', 'Charleston, SC'): '641.00', ('Atlanta, GA', 'Akron, OH'): '528.00', ('Charlottesville, VA', 'Atlanta, GA'): '457.00', ('Detroit, MI', 'Lansing, MI'): '74.00', ('Atlanta, GA', 'Knoxville, TN'): '152.00', ('Cincinnati, OH', 'Baltimore, MD'): '430.00', ('Knoxville, TN', 'Atlanta, GA'): '152.00', ('Atlanta, GA', 'Asheville, NC'): '164.00', ('Madison, WI', 'New York, NY'): '812.00', ('Minneapolis, MN', 'Rochester, NY'): '783.00', ('Nashville, TN', 'Detroit, MI'): '456.00', ('Detroit, MI', 'Nashville, TN'): '456.00', ('Grand Rapids, MI', 'New York, NY'): '618.00', ('Atlanta, GA', 'New Bern/Morehead/Beaufort, NC'): '433.00', ('Greensboro/High Point, NC', 'Atlanta, GA'): '306.00', ('Atlanta, GA', 'Alexandria, LA'): '500.00', ('Detroit, MI', 'Syracuse, NY'): '374.00', ('St. Louis, MO', 'Detroit, MI'): '440.00', ('Dallas/Fort Worth, TX', 'Cincinnati, OH'): '812.00', ('Minneapolis, MN', 'Dayton, OH'): '574.00', ('Nashville, TN', 'New York, NY'): '764.00', ('Greer, SC', 'Atlanta, GA'): '153.00', ('New York, NY', 'Nashville, TN'): '764.00', ('Chicago, IL', 'Cincinnati, OH'): '264.00', ('Atlanta, GA', 'Allentown/Bethlehem/Easton, PA'): '692.00', ('New York, NY', 'Washington, DC'): '213.00', ('Cincinnati, OH', 'Detroit, MI'): '229.00', ('New York, NY', 'Richmond, VA'): '292.00', ('Atlanta, GA', 'Baton Rouge, LA'): '448.00', ('Atlanta, GA', 'Columbia, SC'): '192.00', ('Baton Rouge, LA', 'Atlanta, GA'): '448.00', ('Columbia, SC', 'Atlanta, GA'): '192.00', ('Atlanta, GA', 'Tulsa, OK'): '674.00', ('Boston, MA', 'New York, NY'): '184.00', ('Tulsa, OK', 'Atlanta, GA'): '674.00', ('Boston, MA', 'Richmond, VA'): '474.00', ('New York, NY', 'Charlottesville, VA'): '305.00', ('Philadelphia, PA', 'Cincinnati, OH'): '507.00', ('Lexington, KY', 'Detroit, MI'): '296.00', ('Atlanta, GA', 'Cedar Rapids/Iowa City, IA'): '694.00', ('Cedar Rapids/Iowa City, IA', 'Atlanta, GA'): '694.00', ('Buffalo, NY', 'New York, NY'): '292.00', ('Detroit, MI', 'Rochester, NY'): '296.00', ('New York, NY', 'Buffalo, NY'): '292.00', ('Boston, MA', 'Newark, NJ'): '200.00', ('Newark, NJ', 'Boston, MA'): '200.00', ('Charlotte, NC', 'New York, NY'): '544.00', ('New York, NY', 'Savannah, GA'): '722.00', ('Jacksonville, FL', 'Raleigh/Durham, NC'): '407.00', ('Richmond, VA', 'Detroit, MI'): '456.00', ('Atlanta, GA', 'Jacksonville/Camp Lejeune, NC'): '399.00', ('Atlanta, GA', 'Huntsville, AL'): '151.00', ('Charlotte, NC', 'Cincinnati, OH'): '335.00', ('Huntsville, AL', 'Atlanta, GA'): '151.00', ('Hartford, CT', 'Minneapolis, MN'): '1050.00', ('Cincinnati, OH', 'New York, NY'): '589.00', ('Madison, WI', 'Minneapolis, MN'): '228.00', ('New York, NY', 'Syracuse, NY'): '198.00', ('Syracuse, NY', 'New York, NY'): '198.00', ('Atlanta, GA', 'Charlottesville, VA'): '457.00', ('Raleigh/Durham, NC', 'Baltimore, MD'): '255.00', ('Fayetteville, AR', 'Atlanta, GA'): '589.00', ('Detroit, MI', 'Green Bay, WI'): '287.00', ('Green Bay, WI', 'Detroit, MI'): '287.00', ('Atlanta, GA', 'Shreveport, LA'): '551.00', ('Shreveport, LA', 'Atlanta, GA'): '551.00', ('New Bern/Morehead/Beaufort, NC', 'Atlanta, GA'): '433.00', ('Pittsburgh, PA', 'Minneapolis, MN'): '726.00', ('Asheville, NC', 'Atl ...

# %%
print(origins)
print(destinations)
print(len(origins))
print(len(destinations))  # one more origin than destination
# Out:
# ['Appleton, WI', 'New York, NY', 'Detroit, MI', 'Traverse City, MI', 'Atlanta, GA', 'Cleveland, OH', 'White Plains, NY', 'Cincinnati, OH', 'Evansville, IN', 'Indianapolis, IN', 'Alexandria, LA', 'Richmond, VA', 'Charlottesville, VA', 'Knoxville, TN', 'Madison, WI', 'Minneapolis, MN', 'Nashville, TN', 'Grand Rapids, MI', 'Greensboro/High Point, NC', 'St. Louis, MO', 'Dallas/Fort Worth, TX', 'Greer, SC', 'Chicago, IL', 'Baton Rouge, LA', 'Columbia, SC', 'Boston, MA', 'Tulsa, OK', 'Philadelphia, PA', 'Lexington, KY', 'Cedar Rapids/Iowa City, IA', 'Buffalo, NY', 'Newark, NJ', 'Charlotte, NC', 'Jacksonville, FL', 'Huntsville, AL', 'Hartford, CT', 'Syracuse, NY', 'Raleigh/Durham, NC', 'Fayetteville, AR', 'Green Bay, WI', 'Shreveport, LA', 'New Bern/Morehead/Beaufort, NC', 'Pittsburgh, PA', 'Asheville, NC', 'Baltimore, MD', 'Savannah, GA', 'Columbus, OH', 'Dayton, OH', 'Bloomington/Normal, IL', 'Little Rock, AR', 'Springfield, MO', 'Kansas City, MO', 'Lansing, MI', 'Wilmington, NC', 'Des Moines, IA', 'Chattanooga, TN', 'Harrisburg, PA', 'Akron, OH', 'Jackson/Vicksburg, MS', 'Valparaiso, FL', 'Birmingham, AL', 'Portland, ME', 'Lafayette, LA', 'Key West, FL', 'Gainesville, FL', 'Manchester, NH', 'Mosinee, WI', 'Bristol/Johnson City/Kingsport, TN', 'Charleston, SC', 'Norfolk, VA', 'Newport News/Williamsburg, VA', 'Columbus, GA', 'Gulfport/Biloxi, MS', 'Harlingen/San Benito, TX', 'Mobile, AL', 'Washington, DC', 'Houston, TX', 'Fargo, ND', 'Tallahassee, FL', 'Myrtle Beach, SC', 'Burlington, VT', 'Flint, MI', 'Bangor, ME', 'Saginaw/Bay City/Midland, MI', 'Rochester, NY', 'Orlando, FL', 'Rochester, MN', 'Milwaukee, WI', 'Augusta, GA', 'New Orleans, LA', 'Jacksonville/Camp Lejeune, NC', 'Charleston/Dunbar, WV', 'Memphis, TN', 'Minot, ND', 'Allentown/Bethlehem/Easton, PA', 'Fort Myers, FL', 'Lincoln, NE', 'Moline, IL', 'Omaha, NE', 'Montgomery, AL', 'Tampa, FL', 'Louisville, KY', 'Roanoke, VA', 'Elmira/Corning, NY', 'Kalamazoo, MI', 'Austin, TX', 'Providence, RI', 'Los Angeles, CA', 'Phoenix, AZ', 'Las Vegas, NV', 'Fort Lauderdale, FL', 'Miami, FL', 'Seattle, WA', 'Kona, HI', 'West Palm Beach/Palm Beach, FL', 'Charlotte Amalie, VI', 'San Diego, CA', 'Albuquerque, NM', 'Kahului, HI', 'Salt Lake City, UT', 'San Francisco, CA', 'Sacramento, CA', 'San Antonio, TX', 'Denver, CO', 'Pensacola, FL', 'El Paso, TX', 'Lubbock, TX', 'Ontario, CA', 'Palm Springs, CA', 'Fresno, CA', 'Santa Ana, CA', 'Reno, NV', 'Melbourne, FL', 'Oakland, CA', 'Spokane, WA', 'Colorado Springs, CO', 'San Juan, PR', 'Santa Barbara, CA', 'San Jose, CA', 'Montrose/Delta, CO', 'Tucson, AZ', 'Burbank, CA', 'Bozeman, MT', 'Midland/Odessa, TX', 'Eagle, CO', 'Honolulu, HI', 'Gunnison, CO', 'Lihue, HI', 'Hayden, CO', 'Jackson, WY', 'Portland, OR', 'Boise, ID', 'Oklahoma City, OK', 'Christiansted, VI', 'Albany, NY', 'Mission/McAllen/Edinburg, TX', 'Wichita, KS', 'Daytona Beach, FL', 'Sarasota/Bradenton, FL', 'Amarillo, TX', 'Kodiak, AK', 'Anchorage, AK', 'Bethel, AK', 'Barrow, AK', 'Deadhorse, AK', 'Fairbanks, AK', 'Ketchikan, AK', 'Juneau, AK', 'Sitka, AK', 'Petersburg, AK', 'Wrangell, AK', 'Nome, AK', 'Kotzebue, AK', 'Adak Island, AK', 'Cordova, AK', 'Yakutat, AK', 'Long Beach, CA', 'Aguadilla, PR', 'Worcester, MA', 'Ponce, PR', 'Newburgh/Poughkeepsie, NY', 'Dallas, TX', 'Panama City, FL', 'Sioux Falls, SD', 'Bismarck/Mandan, ND', 'Fayetteville, NC', 'Billings, MT', 'Missoula, MT', 'Kalispell, MT', 'Scranton/Wilkes-Barre, PA', 'Rapid City, SD', 'Brownsville, TX', 'Corpus Christi, TX', 'South Bend, IN', 'Killeen, TX', 'Monroe, LA', 'Erie, PA', 'Lake Charles, LA', 'Laredo, TX', 'College Station/Bryan, TX', 'Trenton, NJ', 'Islip, NY', 'Tyler, TX', 'Clarksburg/Fairmont, WV', 'Ogdensburg, NY', 'Medford, OR', 'Sanford, FL', 'St. Petersburg, FL', 'Rockford, IL', 'Punta Gorda, FL', 'Stockton, CA', 'Santa Maria, CA', 'Bellingham, WA', 'Fort Wayne, IN', 'St. Cloud, MN', 'Idaho Falls, ID', 'Peoria, IL', 'Concord, NC', 'Toledo, OH', 'State College, PA', 'Eugene, OR', 'Grand Junction, CO', 'Prov ...
# ['Atlanta, GA', 'Portland, ME', 'Des Moines, IA', 'Traverse City, MI', 'Detroit, MI', 'White Plains, NY', 'New York, NY', 'Cleveland, OH', 'Evansville, IN', 'Newark, NJ', 'Boston, MA', 'Baltimore, MD', 'Minneapolis, MN', 'Charleston, SC', 'Akron, OH', 'Lansing, MI', 'Knoxville, TN', 'Asheville, NC', 'Rochester, NY', 'Nashville, TN', 'New Bern/Morehead/Beaufort, NC', 'Alexandria, LA', 'Syracuse, NY', 'Cincinnati, OH', 'Dayton, OH', 'Allentown/Bethlehem/Easton, PA', 'Washington, DC', 'Richmond, VA', 'Baton Rouge, LA', 'Columbia, SC', 'Tulsa, OK', 'Charlottesville, VA', 'Cedar Rapids/Iowa City, IA', 'Buffalo, NY', 'Savannah, GA', 'Raleigh/Durham, NC', 'Jacksonville/Camp Lejeune, NC', 'Huntsville, AL', 'Green Bay, WI', 'Shreveport, LA', 'Manchester, NH', 'Charlotte, NC', 'Gainesville, FL', 'Grand Rapids, MI', 'Key West, FL', 'Pittsburgh, PA', 'Columbus, OH', 'Chattanooga, TN', 'Bloomington/Normal, IL', 'Little Rock, AR', 'Indianapolis, IN', 'Rochester, MN', 'Chicago, IL', 'Lexington, KY', 'Hartford, CT', 'Wilmington, NC', 'Jackson/Vicksburg, MS', 'Augusta, GA', 'Appleton, WI', 'Dallas/Fort Worth, TX', 'Lincoln, NE', 'Valparaiso, FL', 'Birmingham, AL', 'St. Louis, MO', 'Springfield, MO', 'Kansas City, MO', 'Greensboro/High Point, NC', 'Fayetteville, AR', 'Gulfport/Biloxi, MS', 'Newport News/Williamsburg, VA', 'Greer, SC', 'Norfolk, VA', 'Madison, WI', 'Tampa, FL', 'Harlingen/San Benito, TX', 'Bangor, ME', 'Philadelphia, PA', 'Mosinee, WI', 'Houston, TX', 'Burlington, VT', 'Tallahassee, FL', 'Myrtle Beach, SC', 'Bristol/Johnson City/Kingsport, TN', 'Harrisburg, PA', 'Flint, MI', 'Orlando, FL', 'Moline, IL', 'Jacksonville, FL', 'Milwaukee, WI', 'New Orleans, LA', 'Austin, TX', 'Memphis, TN', 'Minot, ND', 'Kalamazoo, MI', 'Fort Myers, FL', 'Lafayette, LA', 'Fargo, ND', 'Saginaw/Bay City/Midland, MI', 'Montgomery, AL', 'Louisville, KY', 'Mobile, AL', 'Elmira/Corning, NY', 'Charleston/Dunbar, WV', 'Omaha, NE', 'Columbus, GA', 'Roanoke, VA', 'Providence, RI', 'Los Angeles, CA', 'Salt Lake City, UT', 'Albuquerque, NM', 'Kahului, HI', 'Miami, FL', 'Las Vegas, NV', 'Phoenix, AZ', 'San Francisco, CA', 'San Diego, CA', 'Seattle, WA', 'Kona, HI', 'Sacramento, CA', 'West Palm Beach/Palm Beach, FL', 'Ontario, CA', 'Fort Lauderdale, FL', 'Tucson, AZ', 'Denver, CO', 'El Paso, TX', 'Lubbock, TX', 'Pensacola, FL', 'Palm Springs, CA', 'San Antonio, TX', 'Fresno, CA', 'Reno, NV', 'Jackson, WY', 'Portland, OR', 'Eagle, CO', 'Melbourne, FL', 'Oakland, CA', 'Colorado Springs, CO', 'San Juan, PR', 'Santa Barbara, CA', 'Albany, NY', 'San Jose, CA', 'Santa Ana, CA', 'Oklahoma City, OK', 'Montrose/Delta, CO', 'Bozeman, MT', 'Midland/Odessa, TX', 'Honolulu, HI', 'Gunnison, CO', 'Lihue, HI', 'Charlotte Amalie, VI', 'Mission/McAllen/Edinburg, TX', 'Hayden, CO', 'Wichita, KS', 'Spokane, WA', 'Amarillo, TX', 'Boise, ID', 'Christiansted, VI', 'Burbank, CA', 'Daytona Beach, FL', 'Sarasota/Bradenton, FL', 'Anchorage, AK', 'Bethel, AK', 'Kodiak, AK', 'Deadhorse, AK', 'Barrow, AK', 'Fairbanks, AK', 'Ketchikan, AK', 'Sitka, AK', 'Juneau, AK', 'Petersburg, AK', 'Wrangell, AK', 'Nome, AK', 'Kotzebue, AK', 'Adak Island, AK', 'Cordova, AK', 'Yakutat, AK', 'Long Beach, CA', 'Aguadilla, PR', 'Ponce, PR', 'Worcester, MA', 'Newburgh/Poughkeepsie, NY', 'Fayetteville, NC', 'Scranton/Wilkes-Barre, PA', 'Billings, MT', 'Bismarck/Mandan, ND', 'Panama City, FL', 'Sioux Falls, SD', 'Kalispell, MT', 'Dallas, TX', 'Missoula, MT', 'Rapid City, SD', 'College Station/Bryan, TX', 'Brownsville, TX', 'Corpus Christi, TX', 'Monroe, LA', 'Erie, PA', 'Killeen, TX', 'Lake Charles, LA', 'Laredo, TX', 'South Bend, IN', 'Trenton, NJ', 'Islip, NY', 'Tyler, TX', 'Grand Junction, CO', 'Sanford, FL', 'St. Petersburg, FL', 'Stockton, CA', 'Punta Gorda, FL', 'Portsmouth, NH', 'Peoria, IL', 'Rockford, IL', 'Clarksburg/Fairmont, WV', 'Fort Wayne, IN', 'Belleville, IL', 'Concord, NC', 'Bellingham, WA', 'Niagara Falls, NY', 'Eugene, OR', 'Hagerstown, MD', 'Grand Forks, ND', 'Pasco/Kennewick/Richland, WA', 'T ...
# 344
# 343

# %%
def possible_destinations(origin):
    return list(set(flights[origin]))

# %%
def find_flight(origin, dest):
    path = [origin]
    start = origin
    layer_destinations = list(set(flights[start]))
    if dest in layer_destinations:
        finish = dest
        path.append(finish)
        searching = False
    else:
        possible_dists = {}
        for possible in layer_destinations:
            if dest in list(set(flights[possible])):
#                 print(possible)
                total_dist = float(distances[(origin, possible)]) + float(distances[(possible, dest)])
                possible_dists[total_dist] = possible
        connection = possible_dists[min(possible_dists.keys())]
        path.append(connection)
        path.append(dest)
        
    return path

# %%
possible_destinations("Rochester, NY")
# Out:
# ['Boston, MA',
#  'New York, NY',
#  'Atlanta, GA',
#  'Fort Myers, FL',
#  'Minneapolis, MN',
#  'Punta Gorda, FL',
#  'Orlando, FL',
#  'Fort Lauderdale, FL',
#  'Sanford, FL',
#  'Philadelphia, PA',
#  'Tampa, FL',
#  'Charlotte, NC',
#  'Baltimore, MD',
#  'Newark, NJ',
#  'Detroit, MI',
#  'Washington, DC',
#  'Chicago, IL']

# %%
find_flight("Rochester, NY", "Las Vegas, NV")
# Out:
# ['Rochester, NY', 'Detroit, MI', 'Las Vegas, NV']

# %%
float(distances[("Burlington, VT", "Chicago, IL")]) + float(distances[("Chicago, IL", 'Los Angeles, CA')])
# Out:
# 2513.0

# %%
float(distances[("Burlington, VT", "New York, NY")]) + float(distances[("New York, NY", 'Los Angeles, CA')])
# Out:
# 2741.0
